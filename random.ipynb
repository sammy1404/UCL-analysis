# %%
import pandas as pd

# %%
df = pd.read_csv('archive/fixtures.csv')
df
# Out:
#      Match Number Round Number              Date  \
# 0               2            1  14/09/2021 16:45
# 1               3            1  14/09/2021 16:45
# 2               1            1  14/09/2021 19:00
# 3               4            1  14/09/2021 19:00
# 4               5            1  14/09/2021 19:00
# ..            ...          ...               ...
# 120           121    SF Game 1  26/04/2022 19:00
# 121           122    SF Game 1  27/04/2022 19:00
# 122           123    SF Game 2  03/05/2022 19:00
# 123           124    SF Game 2  04/05/2022 19:00
# 124           125        Final  28/05/2022 19:00
#
#                           Location    Home Team    Away Team    Group Result
# 0                 Stadion Wankdorf   Young Boys  Man. United  Group F  2 - 1
# 1    Estadio Ramón Sánchez-Pizjuán      Sevilla     Salzburg  Group G  1 - 1
# 2           Estadio de la Cerámica   Villarreal     Atalanta  Group F  2 - 2
# ...

# %%
df
